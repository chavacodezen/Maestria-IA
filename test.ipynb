# %% [markdown]
# <a href="https://colab.research.google.com/github/chavacodezen/Maestria-IA/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome Developer**

# %%
print('Hello')
# Out:
# Hello
