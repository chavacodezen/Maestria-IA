# %% [markdown]
# <a href="https://colab.research.google.com/github/chavacodezen/Maestria-IA/blob/main/Practica21_268838.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 👤 **Estudiante**
# - **Nombre:** Bryan Fernando Chavarria Martinez
# - **Matrícula:** 268838

# %% [markdown]
# # Generalizacion, overfitting y underfitting
# ## Un ejemplo visual con clasificacion
#
# **Sesion 2 — Analitica Predictiva | MIAAD**
#
# ---
#
# Vamos a ver los tres casos en un ejemplo simple y controlado:
#
# | Caso | Que ocurre | Diagnostico |
# |---|---|---|
# | **Underfitting** | El modelo es demasiado simple — no captura el patron | Loss-0-1 alto en train Y en test |
# | **Balance** | El modelo captura el patron real | Loss-0-1 bajo en train, similar en test |
# | **Overfitting** | El modelo memorizo el ruido de train | Loss-0-1 bajo en train, ALTO en test |
#
# **Metrica:** `Loss 0-1` = fraccion de ejemplos mal clasificados (= 1 - accuracy)
#
# ```
# Loss-0-1(h) = (1/N) * sum_i  1[ h(x_i) != y_i ]
# ```
#
# > Usamos dos particiones solamente: **train** y **test**.

# %% [markdown]
# ---
# ## Bloque 0 — Importaciones

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import numpy as np
# Loss 0-1 = 1 - accuracy
def loss_01(y_true, y_pred):
    """Fraccion de ejemplos mal clasificados."""
    return 1.0 - accuracy_score(y_true, y_pred)

print('Listo.')
# Out:
# Listo.

# %% [markdown]
# ---
# ## Bloque 1 — El dataset
#
# Usamos `make_moons`: dos clases con forma de media luna.
# Es un problema que **no se puede resolver con una linea recta** — necesita algo de flexibilidad.
#
# Este es el patron real que existe en los datos (f*).
# El reto: encontrar una h que lo capture sin memorizar el ruido.

# %%
# Generamos el dataset
np.random.seed(42)

#X tiene el conjunto de datos de M x N
#Y es el vector de clases
X, y = make_moons(n_samples=300, noise=0.25, random_state=42)

# Split 70 / 30
# 70% datos de Entrenamiento
# 30% Datos de test
#Devuelve 4 archivos: 2 del conjunto de datos en entrenamiento y test,
# y otros 2 con las etiquetas de clase de entrenamiento y test
# con Random_state agregarmos una semilla
# Estratificamos para cumplir con las probabilidades a priori en entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

print(f'Train: {X_train.shape[0]} ejemplos')
print(f'Test:  {X_test.shape[0]} ejemplos')
print(f'Clases: {np.bincount(y_train)} en train   {np.bincount(y_test)} en test')
# Out:
# Train: 210 ejemplos
# Test:  90 ejemplos
# Clases: [112  98] en train   [38 52] en test

# %%
# Visualizamos el dataset
fig, ax = plt.subplots(figsize=(6, 5))

cmap_pts = ['#1B4F8A', '#BF3B3B']
for clase, color, label in [(0, '#1B4F8A', 'Clase 0'), (1, '#BF3B3B', 'Clase 1')]:
    mask = y_train == clase
    ax.scatter(X_train[mask, 0], X_train[mask, 1],
               c=color, s=40, alpha=0.8, edgecolors='white', lw=0.5, label=f'{label} (train)')
    mask_te = y_test == clase
    ax.scatter(X_test[mask_te, 0], X_test[mask_te, 1],
               c=color, s=40, alpha=0.4, edgecolors='white', lw=0.5,
               marker='s', label=f'{label} (test)')

ax.set_title('Dataset: make_moons con ruido=0.25', fontsize=12)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.legend(fontsize=9, ncol=2)
plt.tight_layout()
plt.show()

print('Circulos = train   Cuadrados = test')
print('El patron real f* tiene forma de dos medias lunas entrelazadas.')
# Out:
# Circulos = train   Cuadrados = test
# El patron real f* tiene forma de dos medias lunas entrelazadas.

# %% [markdown]
# ---
# ## Bloque 2 — Los tres modelos
#
# Usamos `DecisionTreeClassifier` con distintas profundidades.
# `max_depth` controla el tamano del espacio de hipotesis H:
#
# | Modelo | max_depth | H | Riesgo esperado |
# |---|---|---|---|
# | Underfitting | 1 | Muy pequeno — solo un corte | Alto (no captura las lunas) |
# | Balance | 4 | Apropiado para este patron | Bajo (captura la forma) |
# | Overfitting | sin limite | Enorme — memoriza cada punto | Alto (memorizo el ruido) |

# %%
# Entrenamos los tres modelos (h)

#Cada clasificador tiene un paràmetro diferente y creamos el modelo.
# No se ha entrenado
h_under   = DecisionTreeClassifier(max_depth=1, random_state=42)
h_balance = DecisionTreeClassifier(max_depth=4, random_state=42)
h_over    = DecisionTreeClassifier(max_depth=None, random_state=42)  # sin limite


#usando la función fit, entrenamos cada uno de los modelos que fue creado.
#Aquí entrenamos cada uno de los modelos usando el conjunto de entrenamiento
# y la etiqute de clase de entrenamiento
h_under.fit(X_train, y_train)
h_balance.fit(X_train, y_train)
h_over.fit(X_train, y_train)

# Calculamos Loss 0-1 en train y test para cada modelo
modelos = [
    ('Underfitting  (depth=1)',   h_under),
    ('Balance       (depth=4)',   h_balance),
    ('Overfitting   (depth=inf)', h_over),
]

print(f"{'Modelo':<30} {'Loss train':>12} {'Loss test':>12} {'Gap':>10} {'Diagnostico'}")
print('-' * 82)

for nombre, modelo in modelos:
    #Aquí calculamos la pérdida 0-1
    #recibe como entrada el valor de y y el modelo entrenado
    #modelo.predict(X) da como salida el valor y que es la predicción
    l_tr = loss_01(y_train, modelo.predict(X_train))
    l_te = loss_01(y_test,  modelo.predict(X_test))
    gap  = l_te - l_tr   # positivo = overfitting

    print(f'{nombre:<30} {l_tr:>12.3f} {l_te:>12.3f} {gap:>10.3f}')
# Out:
# Modelo                           Loss train    Loss test        Gap Diagnostico
# ----------------------------------------------------------------------------------
# Underfitting  (depth=1)               0.181        0.222      0.041
# Balance       (depth=4)               0.100        0.100      0.000
# Overfitting   (depth=inf)             0.000        0.078      0.078

# %% [markdown]
# ---
# ## Bloque 3 — Visualizacion de las fronteras de decision
#
# La **frontera de decision** es la linea (o curva) que separa las dos clases segun h.
#
# - Frontera recta → modelo simple → H pequeno
# - Frontera suave y curva → modelo apropiado → H mediano
# - Frontera muy irregular → modelo complejo → H grande (memorizo el ruido)

# %%
# Funcion para graficar la frontera de decision
from matplotlib.colors import ListedColormap

import matplotlib.patches as mpatches

def plot_frontera(ax, modelo, X_tr, y_tr, X_te, y_te, titulo, color_titulo):
    h = 0.02
    x_min, x_max = X_tr[:, 0].min() - 0.5, X_tr[:, 0].max() + 0.5
    y_min, y_max = X_tr[:, 1].min() - 0.5, X_tr[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = modelo.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    cmap_bg = ListedColormap(['#D6E4F7', '#FCEBEB'])
    ax.contourf(xx, yy, Z, cmap=cmap_bg, alpha=0.6)
    ax.contour( xx, yy, Z, colors=['#888780'], linewidths=1.2, alpha=0.8)

    for clase, color in [(0, '#1B4F8A'), (1, '#BF3B3B')]:
        m_tr = y_tr == clase
        ax.scatter(X_tr[m_tr, 0], X_tr[m_tr, 1], c=color, s=35,
                   edgecolors='white', lw=0.5, alpha=0.9, zorder=3)
        m_te = y_te == clase
        ax.scatter(X_te[m_te, 0], X_te[m_te, 1], c=color, s=35,
                   marker='s', edgecolors='white', lw=0.5, alpha=0.5, zorder=3)

    # Loss 0-1
    l_tr = loss_01(y_tr, modelo.predict(X_tr))
    l_te = loss_01(y_te, modelo.predict(X_te))
    gap  = l_te - l_tr

    ax.set_title(titulo, fontsize=13, color=color_titulo, fontweight='bold')
    ax.set_xlabel(
        f'Loss train={l_tr:.3f}   Loss test={l_te:.3f}   Gap={gap:+.3f}',
        fontsize=10
    )
    ax.set_xticks([])
    ax.set_yticks([])


fig, axes = plt.subplots(1, 3, figsize=(15, 5))

plot_frontera(axes[0], h_under,   X_train, y_train, X_test, y_test,
              'UNDERFITTING\n(max_depth=1)', '#854F0B')
plot_frontera(axes[1], h_balance, X_train, y_train, X_test, y_test,
              'BALANCE\n(max_depth=4)', '#0F6E56')
plot_frontera(axes[2], h_over,    X_train, y_train, X_test, y_test,
              'OVERFITTING\n(max_depth=sin limite)', '#BF3B3B')

# Leyenda comun
p0  = mpatches.Patch(color='#1B4F8A', label='Clase 0')
p1  = mpatches.Patch(color='#BF3B3B', label='Clase 1')
ptr = plt.Line2D([0],[0], marker='o', color='w', markerfacecolor='gray',
                 markersize=8, label='Train')
pte = plt.Line2D([0],[0], marker='s', color='w', markerfacecolor='gray',
                 markersize=8, label='Test')
fig.legend(handles=[p0, p1, ptr, pte], loc='lower center',
           ncol=4, fontsize=10, bbox_to_anchor=(0.5, -0.02))

plt.suptitle('Fronteras de decision — Loss 0-1 en train y test', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Bloque 4 — La curva de complejidad
#
# Variamos `max_depth` de 1 a 20 y graficamos el Loss 0-1 en train y en test.
#
# La curva muestra el **tradeoff sesgo-varianza** en un solo grafico:
#
# - **Izquierda:** loss train Y test altos → underfitting
# - **Centro:** loss test en su minimo → balance optimo
# - **Derecha:** loss train baja, loss test sube → overfitting

# %%
# Curva de complejidad
#Aquí defino una lista de parámetros a usar en Decision Tree
profundidades = list(range(1, 21))
loss_trains, loss_tests = [], []

#En este ciclo se entrenan y evalúan los modelos de decisión con tree
# con distintos parámetros en la profundidad.
for d in profundidades:
    modelo = DecisionTreeClassifier(max_depth=d, random_state=42)
    modelo.fit(X_train, y_train)
    loss_trains.append(loss_01(y_train, modelo.predict(X_train)))
    loss_tests.append( loss_01(y_test,  modelo.predict(X_test)))

idx_opt   = int(np.argmin(loss_tests))
depth_opt = profundidades[idx_opt]

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(profundidades, loss_trains, 'o-', color='#1B4F8A',
        lw=2, ms=6, label='Loss 0-1 en train   (riesgo empirico)')
ax.plot(profundidades, loss_tests,  's-', color='#BF3B3B',
        lw=2, ms=6, label='Loss 0-1 en test    (riesgo esperado estimado)')

# Punto optimo
ax.axvline(depth_opt, color='#0F6E56', lw=1.8, ls='--', alpha=0.8)
ax.annotate(
    f'Optimo\ndepth={depth_opt}\nLoss test={loss_tests[idx_opt]:.3f}',
    xy=(depth_opt, loss_tests[idx_opt]),
    xytext=(depth_opt + 1.5, loss_tests[idx_opt] + 0.04),
    fontsize=10, color='#0F6E56',
    arrowprops=dict(arrowstyle='->', color='#0F6E56', lw=1.2)
)

# Zonas de color
ax.axvspan(0.5, depth_opt,   alpha=0.06, color='#854F0B')
ax.axvspan(depth_opt, 20.5,  alpha=0.06, color='#BF3B3B')

ax.text(1.2,  0.29, 'Underfitting\n(sesgo alto)',  fontsize=10, color='#854F0B', va='top')
ax.text(depth_opt + 0.3, 0.29, 'Overfitting\n(varianza alta)', fontsize=10, color='#BF3B3B', va='top')

# Marcar los tres casos del Bloque 2
for d, label, col in [(1, 'Depth=1\n(under)', '#854F0B'),
                       (4, 'Depth=4\n(balance)', '#0F6E56'),
                       (20,'Depth=20\n(over)', '#BF3B3B')]:
    y_val = loss_tests[d - 1]
    ax.axvline(d, color=col, lw=1, ls=':', alpha=0.5)

ax.set_xlabel('Complejidad del modelo (max_depth)', fontsize=12)
ax.set_ylabel('Loss 0-1  (fraccion de errores)', fontsize=12)
ax.set_title('Curva de complejidad: underfitting → balance → overfitting', fontsize=13)
ax.set_xlim(0.5, 20.5)
ax.set_ylim(0, 0.32)
ax.legend(fontsize=11)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Práctica 21: Generalización, Overfitting y Underfitting**

# %%
print("1. Cambia los parámetros del conjunto de datos moon, en específico el ruido del dataset a noise = 0.05\n")

np.random.seed(42)

# Usamos sufijos _low para identificar que es el dataset de ruido 0.05
X_low, y_low = make_moons(n_samples=300, noise=0.05, random_state=42)

# Dividimos usando nombres únicos para no borrar el X_train original
X_train_low, X_test_low, y_train_low, y_test_low = train_test_split(
    X_low, y_low, test_size=0.30, random_state=42, stratify=y_low
)

# Visualización comparativa rápida
fig, ax = plt.subplots(figsize=(6, 5))
for clase, color, label in [(0, '#1B4F8A', 'Clase 0'), (1, '#BF3B3B', 'Clase 1')]:
    mask = y_train_low == clase
    ax.scatter(X_train_low[mask, 0], X_train_low[mask, 1], c=color, label=f'{label} (train)')

    mask_te = y_test_low == clase
    ax.scatter(X_test_low[mask_te, 0], X_test_low[mask_te, 1], c=color,
               marker='s', alpha=0.4, label=f'{label} (test)')

ax.set_title('Dataset: make_moons con ruido = 0.05', fontsize=12)
ax.legend()
plt.show()

print('\nCirculos = train   Cuadrados = test')
print("\n*Datos guardados en variables con sufijo 'low'*")
# Out:
# 1. Cambia los parámetros del conjunto de datos moon, en específico el ruido del dataset a noise = 0.05
# Circulos = train   Cuadrados = test
#
# *Datos guardados en variables con sufijo 'low'*

# %%
print("2. Al igual que en cuaderno de práctica, dibuja las curvas de complejidad usando max_depth de 1 a 20\n")

# Definimos el rango de profundidad (1 a 20)
profundidades = list(range(1, 21))
loss_trains_low, loss_tests_low = [], []

# Entrenamos y evaluamos para cada profundidad usando el dataset _low
for d in profundidades:
    modelo_low = DecisionTreeClassifier(max_depth=d, random_state=42)
    modelo_low.fit(X_train_low, y_train_low)

    # Calculamos el Loss 0-1 (usando las variables _low)
    loss_trains_low.append(loss_01(y_train_low, modelo_low.predict(X_train_low)))
    loss_tests_low.append(loss_01(y_test_low,  modelo_low.predict(X_test_low)))

# Encontrar el punto óptimo para este experimento
idx_opt_low = int(np.argmin(loss_tests_low))
depth_opt_low = profundidades[idx_opt_low]

# Graficamos la curva de complejidad
fig, ax = plt.subplots(figsize=(10, 5))

# Graficamos ambas líneas (train y test)
ax.plot(profundidades, loss_trains_low, 'o-', color='#1B4F8A', lw=2, ms=6, label='Loss 0-1 en train   (riesgo empirico)')
ax.plot(profundidades, loss_tests_low,  's-', color='#BF3B3B', lw=2, ms=6, label='Loss 0-1 en test    (riesgo esperado estimado)')

# Marcamos el punto óptimo
ax.axvline(depth_opt_low, color='#0F6E56', lw=1.8, ls='--', alpha=0.8)
ax.annotate(
    f'Optimo\ndepth={depth_opt_low}\nLoss test={loss_tests_low[idx_opt_low]:.3f}',
    xy=(depth_opt_low, loss_tests_low[idx_opt_low]),
    xytext=(depth_opt_low + 1.5, loss_tests_low[idx_opt_low] + 0.04),
    fontsize=10, color='#0F6E56',
    arrowprops=dict(arrowstyle='->', color='#0F6E56', lw=1.2)
)

# Zonas de color Underfitting y Overfitting
ax.axvspan(0.5, depth_opt_low,   alpha=0.06, color='#854F0B')
ax.axvspan(depth_opt_low, 20.5,  alpha=0.06, color='#BF3B3B')

ax.text(1.2,  0.29, 'Underfitting\n(sesgo alto)',  fontsize=10, color='#854F0B', va='top')
ax.text(depth_opt_low + 0.3, 0.29, 'Overfitting\n(varianza alta)', fontsize=10, color='#BF3B3B', va='top')

# Marcar puntos de referencia
for d, col in [(1, '#854F0B'), (4, '#0F6E56'), (20, '#BF3B3B')]:
    ax.axvline(d, color=col, lw=1, ls=':', alpha=0.5)

ax.set_xlabel('Complejidad del modelo (max_depth)', fontsize=12)
ax.set_ylabel('Loss 0-1  (fraccion de errores)', fontsize=12)
ax.set_title('Curva de complejidad (Ruido = 0.05): underfitting → balance → overfitting', fontsize=13)
ax.set_xlim(0.5, 20.5)
ax.set_ylim(0, 0.32)
ax.legend(fontsize=11)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 2. Al igual que en cuaderno de práctica, dibuja las curvas de complejidad usando max_depth de 1 a 20

# %%
print("3. En qué valores de max_depth se observa un overfitting y un underfitting\n")

# Identificamos Underfitting
depth_under = profundidades[0]
loss_te_under = loss_tests_low[0]

# Identificamos Overfitting (Cuando el error de train es 0 pero el de test es mayor)
try:
    depth_over_start = profundidades[loss_trains_low.index(min(loss_trains_low))]
except ValueError:
    depth_over_start = 10

# Valores clave para analisis
print(f"Aalizis de datos (Ruido 0.05)")
print(f"Profundidad Under: 1  -> Test Loss = {loss_te_under:.3f}")
print(f"Profundidad Optimo: {depth_opt_low} -> Test Loss = {loss_tests_low[idx_opt_low]:.3f}")
print(f"Profundidad Max: 20   -> Train Loss = {loss_trains_low[-1]:.3f}, Test Loss = {loss_tests_low[-1]:.3f}\n")

print(f"Se observa UNDERFITTING en max_depth = {depth_under} (ambos errores altos).")
print(f"El OVERFITTING comienza sutilmente a partir de max_depth > {depth_opt_low}, "
      f"donde el error de entrenamiento cae a {min(loss_trains_low):.3f} pero el de test deja de mejorar.")
# Out:
# 3. En qué valores de max_depth se observa un overfitting y un underfitting
#
# Aalizis de datos (Ruido 0.05)
# Profundidad Under: 1  -> Test Loss = 0.211
# Profundidad Optimo: 7 -> Test Loss = 0.000
# Profundidad Max: 20   -> Train Loss = 0.000, Test Loss = 0.000
#
# Se observa UNDERFITTING en max_depth = 1 (ambos errores altos).
# El OVERFITTING comienza sutilmente a partir de max_depth > 7, donde el error de entrenamiento cae a 0.000 pero el de test deja de mejorar.

# %%
print("4. Cambia los parámetros del conjunto de datos moon, en específico el ruido del dataset a noise = 0.40\n")

np.random.seed(42)

# Usamos sufijos _high para identificar que es el dataset de ruido alto (0.40)
X_high, y_high = make_moons(n_samples=300, noise=0.40, random_state=42)

# Dividimos usando nombres únicos para no borrar los conjuntos anteriores (_low o el original)
X_train_high, X_test_high, y_train_high, y_test_high = train_test_split(
    X_high, y_high, test_size=0.30, random_state=42, stratify=y_high
)

# Visualización comparativa rápida
fig, ax = plt.subplots(figsize=(6, 5))
for clase, color, label in [(0, '#1B4F8A', 'Clase 0'), (1, '#BF3B3B', 'Clase 1')]:
    mask = y_train_high == clase
    ax.scatter(X_train_high[mask, 0], X_train_high[mask, 1], c=color, label=f'{label} (train)')

    mask_te = y_test_high == clase
    ax.scatter(X_test_high[mask_te, 0], X_test_high[mask_te, 1], c=color,
               marker='s', alpha=0.4, label=f'{label} (test)')

ax.set_title('Dataset: make_moons con ruido = 0.40', fontsize=12)
ax.legend()
plt.show()

print('\nCirculos = train   Cuadrados = test')
print("\n*Datos guardados en variables con sufijo 'high'*")
# Out:
# 4. Cambia los parámetros del conjunto de datos moon, en específico el ruido del dataset a noise = 0.40
# Circulos = train   Cuadrados = test
#
# *Datos guardados en variables con sufijo 'high'*

# %%
print("5. Al igual que en cuaderno de práctica, dibuja las curvas de complejidad usando max_depth de 1 a 20\n")

# Definimos el rango de profundidad (1 a 20)
profundidades = list(range(1, 21))
loss_trains_high, loss_tests_high = [], []

# En este ciclo se entrenan y evalúan los modelos de decisión con tree
# con distintos parámetros en la profundidad usando el dataset _high
for d in profundidades:
    modelo_high = DecisionTreeClassifier(max_depth=d, random_state=42)
    modelo_high.fit(X_train_high, y_train_high)

    # Calculamos el Loss 0-1 (usando las variables _high)
    loss_trains_high.append(loss_01(y_train_high, modelo_high.predict(X_train_high)))
    loss_tests_high.append(loss_01(y_test_high,  modelo_high.predict(X_test_high)))

# Encontrar el punto óptimo para este experimento (Ruido 0.40)
idx_opt_high = int(np.argmin(loss_tests_high))
depth_opt_high = profundidades[idx_opt_high]

# Graficamos la curva de complejidad
fig, ax = plt.subplots(figsize=(10, 5))

# Graficamos ambas líneas (train y test) con variables _high
ax.plot(profundidades, loss_trains_high, 'o-', color='#1B4F8A',
        lw=2, ms=6, label='Loss 0-1 en train   (riesgo empirico)')
ax.plot(profundidades, loss_tests_high,  's-', color='#BF3B3B',
        lw=2, ms=6, label='Loss 0-1 en test    (riesgo esperado estimado)')

# Marcamos el punto óptimo
ax.axvline(depth_opt_high, color='#0F6E56', lw=1.8, ls='--', alpha=0.8)
ax.annotate(
    f'Optimo\ndepth={depth_opt_high}\nLoss test={loss_tests_high[idx_opt_high]:.3f}',
    xy=(depth_opt_high, loss_tests_high[idx_opt_high]),
    xytext=(depth_opt_high + 1.5, loss_tests_high[idx_opt_high] + 0.15),
    fontsize=10, color='#0F6E56',
    arrowprops=dict(arrowstyle='->', color='#0F6E56', lw=1.2)
)

# Zonas de color Underfitting y Overfitting basadas en el nuevo óptimo
ax.axvspan(0.5, depth_opt_high,   alpha=0.06, color='#854F0B')
ax.axvspan(depth_opt_high, 20.5,  alpha=0.06, color='#BF3B3B')

# Ajustamos la altura de los textos (0.55) para que no choquen con las líneas
ax.text(1.0,  0.55, 'Underfitting\n(sesgo alto)',  fontsize=10, color='#854F0B', va='top')
ax.text(depth_opt_high + 1.0, 0.55, 'Overfitting\n(varianza alta)', fontsize=10, color='#BF3B3B', va='top')

# Marcar puntos de referencia
for d, col in [(1, '#854F0B'), (4, '#0F6E56'), (20, '#BF3B3B')]:
    ax.axvline(d, color=col, lw=1, ls=':', alpha=0.5)

ax.set_xlabel('Complejidad del modelo (max_depth)', fontsize=12)
ax.set_ylabel('Loss 0-1  (fraccion de errores)', fontsize=12)
ax.set_title('Curva de complejidad (Ruido = 0.40): underfitting → balance → overfitting', fontsize=13)
ax.set_xlim(0.5, 20.5)
ax.set_ylim(0, 0.60) # Aumentamos el límite para que el ruido 0.40 sea visible
ax.legend(fontsize=11)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 5. Al igual que en cuaderno de práctica, dibuja las curvas de complejidad usando max_depth de 1 a 20

# %%
print("6. En qué valores de max_depth se observa un overfitting y un underfitting\n")

# Identificamos Underfitting
depth_under_high = profundidades[0]
loss_te_under_high = loss_tests_high[0]

# Identificamos Overfitting (Cuando el error de train es 0 pero el de test es mayor)
try:
    min_tr_high = min(loss_trains_high)
    depth_over_start_high = profundidades[loss_trains_high.index(min_tr_high)]
except ValueError:
    depth_over_start_high = 10

# Valores clave para analisis
print(f"Aalizis de datos (Ruido 0.40)")
print(f"Profundidad Under: 1  -> Test Loss = {loss_te_under_high:.3f}")
print(f"Profundidad Óptimo: {depth_opt_high} -> Test Loss = {loss_tests_high[idx_opt_high]:.3f}")
print(f"Profundidad Max: 20   -> Train Loss = {loss_trains_high[-1]:.3f}, Test Loss = {loss_tests_high[-1]:.3f}\n")

print(f"Se observa UNDERFITTING en max_depth = {depth_under_high} (el modelo es demasiado simple para el ruido 0.40).")
print(f"El OVERFITTING comienza claramente a partir de max_depth > {depth_opt_high}, "
      f"donde el modelo memoriza el ruido (Train Loss -> {min_tr_high:.3f}) y el error de test aumenta significativamente.")
# Out:
# 6. En qué valores de max_depth se observa un overfitting y un underfitting
#
# Aalizis de datos (Ruido 0.40)
# Profundidad Under: 1  -> Test Loss = 0.256
# Profundidad Óptimo: 2 -> Test Loss = 0.178
# Profundidad Max: 20   -> Train Loss = 0.000, Test Loss = 0.200
#
# Se observa UNDERFITTING en max_depth = 1 (el modelo es demasiado simple para el ruido 0.40).
# El OVERFITTING comienza claramente a partir de max_depth > 2, donde el modelo memoriza el ruido (Train Loss -> 0.000) y el error de test aumenta significativamente.
