# %% [markdown]
# <a href="https://colab.research.google.com/github/chavacodezen/Maestria-IA/blob/main/Practica7_268838.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Nombre: Bryan Fernando Chavarria Martinez
# *   Matricula: 268838

# %% [markdown]
# **ACTIVIDAD**
#
# Analisis de un Dataset con Matplotlib
#
# **OBJETIVO**
#
# El objetivo de este ejercicio es que los estudiantes aprendan a cargar y explorar un dataset, y luego utilicen matplotlib para crear gráficos visuales que les permitan analizar e interpretar los datos.
#
# **DATASET**
#
# Para este ejercicio, utilizaremos el famoso dataset Iris de la librería seaborn. Este dataset contiene información sobre diferentes especies de flores Iris y varias medidas de sus características (como el largo y ancho del sépalo y el pétalo). Los estudiantes pueden cargarlo directamente desde la librería seaborn. Para ello emplea la siguiente instrucción:
#
# **df = sns.load_dataset('iris')**
#
# **INSTRUCCIONES**
#
# Carga y exploración del dataset:
#
# *   Cargar el dataset Iris utilizando seaborn o cualquier otro dataset de su elección.
# *   Verificar las primeras filas del dataset con el método .head().
# *   Obtener información general sobre los datos (nombres de columnas, tipos de datos, valores nulos, etc.).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('iris')

print("Primeras filas del dataset Iris:")
print(df.head())

print("\nInformacion general del Dataset:")
df.info()
# Out:
# Primeras filas del dataset Iris:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Informacion general del Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# a) Gráfico de barras:
#
# *   Objetivo: Comparar el promedio de largo y ancho de los pétalos entre las tres especies de Iris.
# *   Instrucciones: Utiliza un gráfico de barras para mostrar la media de las columnas petal_length y petal_width agrupadas por species.

# %%
# Calcular los promedios por especie
promedios = df.groupby('species')[['petal_length', 'petal_width']].mean()
print(promedios)

# Posiciones en el eje X
especies = promedios.index
x = range(len(especies))
# Valores
petal_length_mean = promedios['petal_length']
petal_width_mean = promedios['petal_width']
# Ancho de las barras
width = 0.35

plt.figure()

# Barras
plt.bar(x, petal_length_mean, width, color='skyblue', label='Largo del Petalo')
plt.bar(
    [i + width for i in x],
    petal_width_mean,
    width,
    color='gray',
    label='Ancho del Petalo'
)

# Etiquetas
plt.xlabel('Especie')
plt.ylabel('Promedio')
plt.title('Promedio del largo y ancho del petalo por especie')
plt.xticks([i + width / 2 for i in x], especies)
plt.legend()

plt.show()
# Out:
#             petal_length  petal_width
# species
# setosa             1.462        0.246
# versicolor         4.260        1.326
# virginica          5.552        2.026

# %% [markdown]
# b) Histograma:
#
# *   Objetivo: Visualizar la distribución de los largos de los sépalos (sepal_length).
# *   Instrucciones: Crea un histograma de la variable sepal_length y asegúrate de que tenga un número adecuado de bins. Coloca etiquetas en los ejes y un título.

# %%
# Histograma
plt.figure()
plt.hist(
    df['sepal_length'],
    bins=20,              # barras
    edgecolor='gray',    # bordes
    color='skyblue'
)

# Etiquetas
plt.xlabel('Largo del Sepalo')
plt.ylabel('Frecuencia')
plt.title('Distribucion del largo del sepalo')
plt.show()

# %% [markdown]
# c) Gráfico de dispersión (scatter plot):
#
# *   Objetivo: Relacionar el largo del pétalo con el ancho del pétalo.
# *   Instrucciones: Crea un gráfico de dispersión que compare petal_length con petal_width. Usa un color diferente para cada especie.

# %%
# Colores por especie
colores = {
    'setosa': 'gray',
    'versicolor': 'skyblue',
    'virginica': 'blue'
}

# Scatter por especie
plt.figure()
for especie in df['species'].unique():
    subset = df[df['species'] == especie]
    plt.scatter(
        subset['petal_length'],
        subset['petal_width'],
        color=colores[especie],
        label=especie,
        alpha=0.7
    )

# Etiquetas
plt.xlabel('Largo del Petalo')
plt.ylabel('Ancho del Petalo')
plt.title('Relacion entre largo y ancho del petalo por especie')
plt.legend()
plt.show()

# %% [markdown]
# d) Gráfico de cajas (box plot):
#
# *   Objetivo: Analizar la distribución de las medidas del sépalo (sepal_length, sepal_width).
# *   Instrucciones: Crea un gráfico de cajas para mostrar la distribución de las variables sepal_length y sepal_width por especie.

# %%
plt.figure(figsize=(10, 5))

# BoxPlot
plt.subplot(1, 2, 1)
sns.boxplot(x='species', y='sepal_length', data=df, color='skyblue')
plt.title('Largo del Sepalo por especie')

# BoxPlot
plt.subplot(1, 2, 2)
sns.boxplot(x='species', y='sepal_width', data=df, color='blue')
plt.title('Ancho del Sepalo por especie')

plt.tight_layout()
plt.show()

# %% [markdown]
# e) Gráfico de líneas:
#
# *   Objetivo: Mostrar la tendencia de la longitud del pétalo (petal_length) a través de las observaciones.
# *   Instrucciones: Crea un gráfico de líneas utilizando la variable petal_length (en el eje Y) con el índice de las observaciones (en el eje X). Puedes hacer esto para ver cómo varía la longitud del pétalo a lo largo del dataset.

# %%
# Grafico de lineas
plt.figure()
plt.plot(
    df.index,
    df['petal_length'],
    color='blue',
    linewidth=1
)

# Etiquetas
plt.xlabel('Indice de la observacion')
plt.ylabel('Largo del Petalo')
plt.title('Tendencia de la longitud del petalo a lo largo del dataset')
plt.show()

# %% [markdown]
# Formato y personalización de los gráficos:
#
# *   Asegúrate de personalizar cada gráfico con títulos, etiquetas en los ejes, y leyendas cuando sea necesario.
# *   Experimenta con diferentes colores, tamaños de figura y estilos de línea.
